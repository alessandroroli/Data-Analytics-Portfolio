# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Pulizia e analisi preliminare del file riguardante la **composizione demografica** dei clienti di **TheLook eCommerce**.

# %%
dc = pd.read_csv('demographic_composition.csv')
dc
# Out:
#        user_id gender  age                                 state  \
# 0        41110      F   49                                  Acre
# 1        43685      F   13                                  Acre
# 2        75218      F   65                                  Acre
# 3        82190      M   57                                  Acre
# 4        83792      M   34                                  Acre
# ...        ...    ...  ...                                   ...
# 99995    27804      F   41  Jeju Special Self-Governing Province
# 99996    40781      F   45  Jeju Special Self-Governing Province
# 99997    50723      F   40  Jeju Special Self-Governing Province
# 99998    63116      F   24  Jeju Special Self-Governing Province
# 99999    63867      F   47  Jeju Special Self-Governing Province
#
#                 city      country   latitude   longitude traffic_source  \
# 0         Rio Branco       Brasil  -9.945568  -67.835610         Search
# 1         Rio Branco       Brasil  -9.945568  -67.835610         Search
# 2         Rio Branco       Brasil  -9.945568  -67.835610         Search
# 3         Rio Branco       Brasil  -9.945568  -67.835610        Organic
# 4         Rio Branco       Brasil  -9.945568  -67.835610         Search
# ...              ...          ...        ...         ...            ...
# 99995  Seogwipo City  South Korea  33.305744  126.675429         Search
# 99996  Seogwipo City  South Korea  33.305744  126.675429        Organic
# 99997  Seogwipo City  South Korea  33.305744  126.675429         Search
# 99998  Seogwipo City  South Korea  33.305744  126.675429         Search
# 99999  Seogwipo City  South Korea  33.305744  126.675429         Search
#
#        num_orders  avg_items_per_order
# 0               4                 1.25
# 1               1                 1.00
# 2               0                  NaN
# 3               0                  NaN
# 4               1                 3.00
# ...           ...                  ...
# 99995           1                 1.00
# 99996           1                 1.00
# 99997           1                 1.00
# 99998           1                 1.00
# 99999           2                 1.50
#
# [100000 rows x 11 columns]

# %%
dc.dtypes
# Out:
# user_id                  int64
# gender                  object
# age                      int64
# state                   object
# city                    object
# country                 object
# latitude               float64
# longitude              float64
# traffic_source          object
# num_orders               int64
# avg_items_per_order    float64
# dtype: object

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   user_id              100000 non-null  int64
#  1   gender               100000 non-null  object
#  2   age                  100000 non-null  int64
#  3   state                100000 non-null  object
#  4   city                 99019 non-null   object
#  5   country              100000 non-null  object
#  6   latitude             100000 non-null  float64
#  7   longitude            100000 non-null  float64
#  8   traffic_source       100000 non-null  object
#  9   num_orders           100000 non-null  int64
#  10  avg_items_per_order  79920 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 8.4+ MB

# %%
# Sostituisco i valori 'null' nell colonna 'City' con 'Unknown'

dc['city'].fillna('Unknown', inplace=True)

# %%
righe_con_unknown = dc[dc['city'] == 'Unknown']
righe_con_unknown
# Out:
#        user_id gender  age                 state     city country   latitude  \
# 24         972      F   47                  Acre  Unknown  Brasil  -8.065346
# 25        2792      M   42                  Acre  Unknown  Brasil  -8.065346
# 26       23106      F   33                  Acre  Unknown  Brasil  -8.065346
# 27       30737      F   59                  Acre  Unknown  Brasil  -8.065346
# 28       48216      F   15                  Acre  Unknown  Brasil  -8.065346
# ...        ...    ...  ...                   ...      ...     ...        ...
# 95976    36151      F   26  Comunidad Valenciana  Unknown   Spain  39.478079
# 96068    27311      F   38  Comunidad Valenciana  Unknown   Spain  39.513440
# 96069    38936      M   69  Comunidad Valenciana  Unknown   Spain  39.513440
# 96070    50409      F   19  Comunidad Valenciana  Unknown   Spain  39.513440
# 96071    51799      F   70  Comunidad Valenciana  Unknown   Spain  39.513440
#
#        longitude traffic_source  num_orders  avg_items_per_order
# 24    -72.870949         Search           3                  2.0
# 25    -72.870949         Search           1                  2.0
# 26    -72.870949        Organic           2                  2.5
# 27    -72.870949       Facebook           0                  NaN
# 28    -72.870949         Search           1                  1.0
# ...          ...            ...         ...                  ...
# 95976  -0.557213         Search           1                  1.0
# 96068  -0.455715         Search           1                  1.0
# 96069  -0.455715         Search           2                  2.0
# 96070  -0.455715         Search           2                  1.0
# 96071  -0.455715         Search           2                  1.0
#
# [981 rows x 11 columns]

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   user_id              100000 non-null  int64
#  1   gender               100000 non-null  object
#  2   age                  100000 non-null  int64
#  3   state                100000 non-null  object
#  4   city                 100000 non-null  object
#  5   country              100000 non-null  object
#  6   latitude             100000 non-null  float64
#  7   longitude            100000 non-null  float64
#  8   traffic_source       100000 non-null  object
#  9   num_orders           100000 non-null  int64
#  10  avg_items_per_order  79920 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 8.4+ MB

# %%
# Numero di clienti maschi e femmine distinti

gender_counts = dc['gender'].value_counts()

print("Numero di clienti maschi:", gender_counts['M'])
print("Numero di clienti femmine:", gender_counts['F'])
# Out:
# Numero di clienti maschi: 49826
# Numero di clienti femmine: 50174

# %%
# Plot Distribuzione del Genere (M,F)

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(x='gender', data=dc)
plt.title('Distribuzione di genere')
# Out:
# Text(0.5, 1.0, 'Distribuzione di genere')

# %%
# Violin Plot per Distribuzione dell'Età

plt.figure(figsize=(10, 6))
sns.violinplot(y='age', data=dc)
plt.title('Distribuzione dell\'età')
plt.ylabel('Età')
plt.show()

# %%
# Numero di ordini per genere

result_df = dc.groupby('gender')['num_orders'].sum().reset_index()
result_df
# Out:
#   gender  num_orders
# 0      F       62890
# 1      M       62114

# %%
# Numero di clienti per country (top 5)

top_5_countries = dc['country'].value_counts().head(5)
top_5_countries
# Out:
# China             33970
# United States     22349
# Brasil            14664
# South Korea        5258
# United Kingdom     4683
# Name: country, dtype: int64

# %%
# Plot Distribuzione dei Clienti per Paese (Top 5)

plt.figure(figsize=(12, 6))
sns.countplot(x='country', data=dc, palette='viridis', order=dc['country'].value_counts().head(5).index)
plt.title('Distribuzione dei clienti per paese')
plt.xlabel('Paese')
plt.ylabel('Numero di clienti')
plt.xticks(rotation=45)
plt.show()

# %%
# Check sulla colonna 'Country'

dc['country'].unique()
# Out:
# array(['Brasil', 'Japan', 'United States', 'China', 'South Korea',
#        'Spain', 'France', 'United Kingdom', 'Germany', 'Colombia',
#        'Belgium', 'Poland', 'Australia', 'Austria'], dtype=object)

# %%
# Sistemo le righe con 'Espana' nella colonna country rimpiazzandole con 'Spain'

dc['country'].replace('España', 'Spain', inplace=True)

# %%
# Numero di clienti per city (top 3)

dc['city'].value_counts().head(3)
# Out:
# Shanghai    2495
# Beijing     2047
# Seoul       1477
# Name: city, dtype: int64

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   user_id              100000 non-null  int64
#  1   gender               100000 non-null  object
#  2   age                  100000 non-null  int64
#  3   state                100000 non-null  object
#  4   city                 100000 non-null  object
#  5   country              100000 non-null  object
#  6   latitude             100000 non-null  float64
#  7   longitude            100000 non-null  float64
#  8   traffic_source       100000 non-null  object
#  9   num_orders           100000 non-null  int64
#  10  avg_items_per_order  79920 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 8.4+ MB

# %%
dc.to_csv('demographic_composition_cleaned2.csv')

# %%
# EXTRA (lavoro sulla colonna 'state' correggendo alcuni errori che ho riscontrato nel file)

dc['state'].unique()
# Out:
# array(['Acre', 'Gifu', 'Iowa', 'Nara', 'Ohio', 'Oita', 'Utah', 'Aichi',
#        'Akita', 'Anhui', 'Bahia', 'Busan', 'Ceuta', 'Chiba', 'Corse',
#        'Gunma', 'Hebei', 'Henan', 'Hubei', 'Hunan', 'Hyogo', 'Idaho',
#        'Iwate', 'Jilin', 'Kochi', 'Kyoto', 'Maine', 'Osaka', 'Pará',
#        'Seoul', 'Shiga', 'Texas', 'Tokyo', 'Wales', 'Alaska', 'Amapá',
#        'Aomori', 'Bayern', 'Berlin', 'Bremen', 'Ceará', 'Fujian', 'Goiás',
#        'Hainan', 'Hawaii', 'Hessen', 'Kagawa', 'Kansas', 'Miyagi',
#        'Nagano', 'Nevada', 'Oregon', 'Piauí', 'Shanxi', 'Yunnan',
#        'Alabama', 'Alagoas', 'Aragón', 'Arizona', 'Beijing', 'Daejeon',
#        'England', 'Florida', 'Fukuoka', 'Galicia', 'Georgia', 'Guizhou',
#        'Gwangju', 'Hamburg', 'Ibaraki', 'Indiana', 'Jiangsu', 'Jiangxi',
#        'Melilla', 'Montana', 'Navarra', 'Okayama', 'Okinawa', 'Paraná',
#        'Qinghai', 'Roraima', 'Sachsen', 'Saitama', 'Sergipe', 'Shaanxi',
#        'Sichuan', 'Tianjin', 'Tochigi', 'Vermont', 'Wyoming', 'Amazonas',
#        'Arkansas', 'Bretagne', 'Brussels', 'Canarias', 'Colorado',
#        'Delaware', 'Flanders', 'Hokkaido', 'Illinois', 'Kanagawa',
#        'Kentucky', 'Kumamoto', 'La Rioja', 'Liaoning', 'Lubuskie',
#        'Maryland', 'Michigan', 'Missouri', 'Miyazaki', 'Nagasaki',
#        'Nebraska', 'New York', 'Oklahoma', 'Paraíba', 'Saarland',
#        'Scotland', 'Shandong', 'Shanghai', 'Shizuoka', 'Tasmania',
#        'Victoria', 'Virginia', 'Wakayama', 'Wallonia', 'Zhejiang',
#        'Cantabria', 'Cataluña', 'Chongqing', 'Fukushima', 'Grand Est',
#        'Guangdong', 'Hiroshima', 'Kagoshima', 'Louisiana', 'Maranhão',
#        'Minnesota', 'Normandie', 'Occitanie', 'Rondônia', 'Tennessee',
#        'Tocantins', 'Wisconsin', 'Yamaguchi', 'Yamanashi', 'Andalucía',
#        'California', 'Gangwon-do', 'New Jersey', 'New Mexico',
#        'Pernambuco', 'Queensland', 'São Paulo', 'Thüringen', 'Vorarlberg',
#        'Washington', 'Brandenburg', 'Connecticut', 'Extremadura',
#        'Gyeonggi-do', 'Mato Grosso', 'Mississippi', 'País Vasco',
#        'Heilongjiang', 'Jeollabuk do', 'Jeollanam-do', 'Minas Gerais',
#        'North Dakota', 'Pennsylvania', 'Rhode Island', 'South Dakota',
#        'Massachusetts', 'New Hampshire', 'Niedersachsen', 'West Virginia',
#        'Bagmati region', 'Dolnośląskie', 'Gansu province',
#        'Islas Baleares', 'North Carolina', 'Rio de Janeiro',
#        'Sachsen-Anhalt', 'Santa Catarina', 'South Carolina',
#        'Île-de-France', 'Espírito Santo', 'Hauts-de-France',
#        'New South Wales', 'Rheinland-Pfalz', 'South Australia',
#        'Castilla y León', 'Distrito Federal', 'Gyeongsangbuk-do',
#        'Gyeongsangnam-do', 'Northern Ireland', 'Pays de la Loire',
#        'Remote territory', 'Chungcheongnam-do', 'Región de Murcia',
#        'Rio Grande do Sul', 'Western Australia', 'Baden-Württemberg',
#        'Castilla-La Mancha', 'Chung-cheong bukdo', 'Mato Grosso do Sul',
#        'Northern Territory', 'Nouvelle-Aquitaine', 'Schleswig-Holstein',
#        'Zachodniopomorskie', 'Centre-Val de Loire', 'Comunidad de Madrid',
#        'Nordrhein-Westfalen', 'Rio Grande do Norte',
#        'Comunidad Valenciana', 'District of Columbia',
#        'Auvergne-Rhône-Alpes', 'Mecklenburg-Vorpommern',
#        'Principado de Asturias', 'Daegu Metropolitan City',
#        'Ulsan Metropolitan City', 'Bourgogne-Franche-Comté',
#        'Incheon Metropolitan City', "Provence-Alpes-Côte d'Azur",
#        'Australian Capital Territory', 'Ningxia Hui Autonomous Region',
#        'Guangxi Zhuang Autonomous Region',
#        'Inner Mongolia Autonomous Region',
#        'Xinjiang Uygur Autonomous Region',
#        'Jeju Special Self-Governing Province'], dtype=object)

# %% [markdown]
# Gli 'state' che presentano delle discrepanze per quanto riguarda city e country sono: **Bagmati Region** e **Remote Territory**.
#
# Bagmati Region e Remote Territory, facendo un check sulle coordinate geografiche su Maps, sono regioni del Nepal e non della Cina.
#
# Data la poca significatività del campione abbiamo deciso di non considerarli nel file finale e quindi di non modificare i valori per questi 'state'.
#
# Lascio comunque il codice qui sotto che mostra come sistemare l'errore.

# %%
bagmati_region = dc[dc['state'] == 'Bagmati region']
bagmati_region
# Out:
#        user_id gender  age           state          city country   latitude  \
# 83382     1947      M   13  Bagmati region  Gaurishankar   Nepal  27.774036
# 83383     3596      M   56  Bagmati region  Gaurishankar   Nepal  27.774036
# 83384     4589      M   55  Bagmati region  Gaurishankar   Nepal  27.774036
# 83385    20942      M   51  Bagmati region  Gaurishankar   Nepal  27.774036
# 83386    24815      M   49  Bagmati region  Gaurishankar   Nepal  27.774036
# 83387    26796      F   27  Bagmati region  Gaurishankar   Nepal  27.774036
# 83388    29364      M   12  Bagmati region  Gaurishankar   Nepal  27.774036
# 83389    30077      F   28  Bagmati region  Gaurishankar   Nepal  27.774036
# 83390    34257      M   38  Bagmati region  Gaurishankar   Nepal  27.774036
# 83391    36141      F   41  Bagmati region  Gaurishankar   Nepal  27.774036
# 83392    37607      M   15  Bagmati region  Gaurishankar   Nepal  27.774036
# 83393    39899      M   15  Bagmati region  Gaurishankar   Nepal  27.774036
# 83394    42832      M   21  Bagmati region  Gaurishankar   Nepal  27.774036
# 83395    46368      M   46  Bagmati region  Gaurishankar   Nepal  27.774036
# 83396    57206      M   59  Bagmati region  Gaurishankar   Nepal  27.774036
# 83397    58689      F   61  Bagmati region  Gaurishankar   Nepal  27.774036
# 83398    76053      M   22  Bagmati region  Gaurishankar   Nepal  27.774036
# 83399    83366      F   44  Bagmati region  Gaurishankar   Nepal  27.774036
# 83400    86273      F   60  Bagmati region  Gaurishankar   Nepal  27.774036
# 83401    89822      M   62  Bagmati region  Gaurishankar   Nepal  27.774036
# 83402    93161      F   55  Bagmati region  Gaurishankar   Nepal  27.774036
# 83403    98859      M   58  Bagmati region  Gaurishankar   Nepal  27.774036
#
#        longitude traffic_source  num_orders  avg_items_per_order
# 83382    86.2042        Organic           1                  3.0
# 83383    86.2042         Search           1                  3.0
# 83384    86.2042         Search           0                  NaN
# 83385    86.2042          Email           0                  NaN
# 83386    86.2042        Organic           0                  NaN
# 83387    86.2042         Search           1                  1.0
# 83388    86.2042          Email           0                  NaN
# 83389    86.2042         Search           0                  NaN
# 83390    86.2042       Facebook           1                  1.0
# 83391    86.2042         Search           1                  2.0
# 83392    86.2042          Email           1                  2.0
# 83393    86.2042         Search           0                  NaN
# 83394    86.2042         Search           2                  1.5
# 83395    86.2042        Organic           0                  NaN
# 83396    86.2042         Search           0                  NaN
# 83397    86.2042          Email           0                  NaN
# 83398    86.2042        Display           3                  1.0
# 83399    86.2042         Search           0                  NaN
# 83400    86.2042         Search           0                  NaN
# 83401    86.2042         Search           3                  1.0
# 83402    86.2042         Search           1                  1.0
# 83403    86.2042         Search           1                  2.0

# %%
# Modifico city e country per Bagmati region

condizione = dc['state'] == 'Bagmati region'
dc.loc[condizione, 'city'] = dc.loc[condizione, 'city'].replace('Beijing', 'Gaurishankar')
dc.loc[condizione, 'country'] = dc.loc[condizione, 'country'].replace('China', 'Nepal')

# %%
remote_territory = dc[dc['state'] == 'Remote territory']
remote_territory
# Out:
#        user_id gender  age             state   city country   latitude  \
# 90440     9747      F   47  Remote territory  Surma   Nepal  29.714174
# 90441    19687      M   61  Remote territory  Surma   Nepal  29.714174
# 90442    23131      M   58  Remote territory  Surma   Nepal  29.714174
# 90443    25717      M   59  Remote territory  Surma   Nepal  29.714174
# 90444    26955      M   33  Remote territory  Surma   Nepal  29.714174
# 90445    32582      F   54  Remote territory  Surma   Nepal  29.714174
# 90446    34000      M   52  Remote territory  Surma   Nepal  29.714174
# 90447    39053      F   19  Remote territory  Surma   Nepal  29.714174
# 90448    39814      F   57  Remote territory  Surma   Nepal  29.714174
# 90449    48617      F   39  Remote territory  Surma   Nepal  29.714174
# 90450    60719      M   12  Remote territory  Surma   Nepal  29.714174
# 90451    61726      M   60  Remote territory  Surma   Nepal  29.714174
# 90452    64125      M   50  Remote territory  Surma   Nepal  29.714174
# 90453    64128      M   42  Remote territory  Surma   Nepal  29.714174
# 90454    64860      F   59  Remote territory  Surma   Nepal  29.714174
# 90455    65384      M   28  Remote territory  Surma   Nepal  29.714174
# 90456    86820      F   19  Remote territory  Surma   Nepal  29.714174
# 90457    86849      F   62  Remote territory  Surma   Nepal  29.714174
# 90458    86966      M   43  Remote territory  Surma   Nepal  29.714174
# 90459    89291      M   48  Remote territory  Surma   Nepal  29.714174
# 90460    93058      M   57  Remote territory  Surma   Nepal  29.714174
# 90461    93671      F   40  Remote territory  Surma   Nepal  29.714174
# 90462    98090      F   19  Remote territory  Surma   Nepal  29.714174
#
#        longitude traffic_source  num_orders  avg_items_per_order
# 90440  81.172431         Search           2                 1.00
# 90441  81.172431         Search           1                 1.00
# 90442  81.172431         Search           2                 1.50
# 90443  81.172431         Search           0                  NaN
# 90444  81.172431         Search           1                 2.00
# 90445  81.172431        Organic           2                 2.00
# 90446  81.172431         Search           1                 1.00
# 90447  81.172431         Search           1                 1.00
# 90448  81.172431         Search           1                 1.00
# 90449  81.172431          Email           0                  NaN
# 90450  81.172431       Facebook           1                 1.00
# 90451  81.172431         Search           4                 1.25
# 90452  81.172431         Search           1                 1.00
# 90453  81.172431         Search           1                 2.00
# 90454  81.172431         Search           1                 1.00
# 90455  81.172431         Search           1                 2.00
# 90456  81.172431         Search           1                 1.00
# 90457  81.172431         Search           1                 1.00
# 90458  81.172431        Display           0                  NaN
# 90459  81.172431        Display           1                 1.00
# 90460  81.172431         Search           1                 1.00
# 90461  81.172431         Search           3                 1.00
# 90462  81.172431         Search           0                  NaN

# %%
# Modifico city e country per Remote territory

condizione = dc['state'] == 'Remote territory'
dc.loc[condizione, 'city'] = dc.loc[condizione, 'city'].replace('Beijing', 'Surma')
dc.loc[condizione, 'country'] = dc.loc[condizione, 'country'].replace('China', 'Nepal')
